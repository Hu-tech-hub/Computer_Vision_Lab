# %% [markdown]
# # Taylor series
#
# * 다음 유튜브 내용을 토대로 제작하였습니다.
#
#     https://www.youtube.com/watch?v=3d6DsjIBzJ4

# %% [markdown]
# > For me, mathematics is  a collection of `examples`; a theorem is a statement about colloection of examples and the purpose of proving theorems is to classify and explain the `examples`
